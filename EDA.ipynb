# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center">
#         <!-- Encabezado -->
#         <p class="titulo">Universidad de Oriente</p>
#         <p class="subtitulo">Núcleo de Anzoátegui</p>
#         <p class="subtitulo">Escuela de Ingeniería</p>
#         <p class="subtitulo">Departamento de Computación y Sistemas</p>
#         <p class="subtitulo">Estructura de Datos</p>
#         <p class="subtitulo">Sección: 01</p>
#         <!-- Logotipo -->
#         <img src="UDO.png" alt="Logo Universidad de Oriente" class="logo">
#         <!--Titulo-->
#         <h1 class="titulo-principal">Análisis Exploratorio de Datos para identificar patrones clave entre los campos de estudio y las ocupaciones laborales
#         </h1>
#         <!--Autores-->
#         <p class="subtitulo">Autores:</p>
#         <p class="subtitulo">Jesús Alcalá</p>
#         <p class="subtitulo">Sebastián Armas</p>
#     </div>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div>
#     <p class= "titulo2" align="center">1.  Planteamineto del problema</p>
#     <p class= "subtitulo2">En la actualidad, el acceso a la educación superior es considerado un derecho clave para el desarrollo personal y profesional. Sin embargo, la eficacia con la que los estudiantes eligen sus campos de estudio y la relación entre estas elecciones y las oportunidades laborales posteriores varía significativamente, además de que el mundo está migrando a un futuro incierto con la influencia de la inteligencia artificial, la cual está trayendo un conjunto de cambios demasiado importantes y de una manera muy rápida. Así como estos,  también hay otros factores (como las universidades en línea) que permiten a los estudiantes aprender a su propio ritmo de una manera más eficiente.
#     </br></br>
#     Esto plantea una pregunta fundamental: ¿los sistemas de selección y orientación en la educación superior garantizan oportunidades que perduran en el tiempo y, a su vez, sean otorgadas a aquellos que las aprovecharán de manera óptima?
#     </br></br>
#     El problema central radica en que, en muchos casos, las decisiones sobre el acceso a estudios superiores no se basan en un análisis profundo de las aptitudes, intereses y proyecciones laborales de los aspirantes. Esto puede resultar en una mala asignación de recursos, altos índices de deserción, y graduados que terminan trabajando en ocupaciones no relacionadas con sus áreas de estudio, muchas veces con menores beneficios económicos y personales.
#     </br></br>
#     Por lo tanto, surge la necesidad de evaluar si el sistema actual de selección para estudios superiores está alineado con los intereses de los estudiantes y las demandas del mercado laboral.
#     </br></br>
#     El dataset Field of Study vs Occupation de Kaggle ofrece una valiosa oportunidad para explorar cómo los campos de estudio se correlacionan con las ocupaciones y otros indicadores laborales, como ingresos, empleabilidad y satisfacción profesional. Al realizar un Análisis Exploratorio de Datos (EDA), es posible identificar patrones clave que evidencian desajustes entre las aspiraciones educativas de los estudiantes y las demandas del mercado laboral.
#     </br></br>
#     A través de este análisis, se busca generar evidencia que pueda fundamentar la creación o mejora de políticas de orientación vocacional y selección, asegurando que las oportunidades educativas se brindan a quienes tengan mayores probabilidades de beneficiarse de ellas, tanto a nivel individual como social.
#
#
# </p>
# </div>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div>
#     <p class= "titulo2" align="center">2. Objetivo general</p>
#     </br></br>
#     <p class= "subtitulo2">Realizar un análisis exploratorio de datos para identificar patrones clave entre los campos de estudio y las ocupaciones laborales, con el fin de evaluar la eficacia del sistema de selección para estudios superiores y proponer mejoras que permitan de una manera eficiente otorgar oportunidades educativas. </p>
#     </br></br>
#     <p class= "titulo2" align="center">3. Objetivos especificos</p>
#     </br></br>
#     <ul class="subtitulo2">
#     <li>Conocer la estructura del dataset <strong>Field of Study vs Occupation</strong>, identificando sus variables clave y comprendiendo su relevancia para el análisis.</li>
#     </br>
#     <li>Analizar la distribución de los campos de estudio para identificar patrones de popularidad y representatividad en la población estudiada.</li>
#     </br>
#     <li>Relacionar los campos de estudio con las ocupaciones laborales, evaluando la concordancia entre ambas dimensiones.</li>
#     </br>
#     <li>Interpretar las diferencias en los ingresos según campo de estudio y ocupación, destacando posibles disparidades significativas.</li>
#     </br>
#     <li>Evaluar las tasas de empleabilidad asociadas a diferentes campos de estudio, identificando áreas con mayor o menor demanda laboral.</li>
#     </br>
#     <li>Crear visualizaciones que resuman de manera clara y efectiva los hallazgos del EDA, facilitando su comprensión e interpretación.</li>
#     </br>
#     <li>Justificar la necesidad de mejorar los sistemas de selección en estudios superiores a partir de los patrones observados en el análisis.</li>
# </ul>
# </div>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div>
#     <p class= "titulo2" align="center">4. Descripción del Dataset "Field of study"</p>
#     </br>
#     <ul class="subtitulo2">
#     <li><strong>Field of Study (Campo de estudio):</strong>
#         <p>Tipo: Categórica (String)</p>
#         <p>Descripción: El área académica en la que se enfocó el individuo durante su educación.</p>
#         <p>Importancia: Permite identificar la relación entre los campos de estudio y las ocupaciones laborales, lo cual es clave para evaluar la alineación educativa y profesional.</p>
#     </li>
#     <li><strong>Current Occupation (Ocupación actual):</strong>
#         <p>Tipo: Categórica (String)</p>
#         <p>Descripción: El trabajo o industria actual del individuo.</p>
#         <p>Importancia: Ayuda a establecer patrones de transición entre campos de estudio y trabajos específicos.</p>
#     </li>
#     <li><strong>Age (Edad):</strong>
#         <p>Tipo: Entero</p>
#         <p>Descripción: La edad del individuo.</p>
#         <p>Importancia: Es útil para analizar tendencias relacionadas con la experiencia y etapas de la carrera profesional.</p>
#     </li>
#     <li><strong>Gender (Género):</strong>
#         <p>Tipo: Categórica (String)</p>
#         <p>Descripción: El género del individuo.</p>
#         <p>Importancia: Permite analizar disparidades de género en ocupaciones e ingresos.</p>
#     </li>
#     <li><strong>Years of Experience (Años de experiencia):</strong>
#         <p>Tipo: Entero</p>
#         <p>Descripción: Los años que el individuo ha estado en la fuerza laboral.</p>
#         <p>Importancia: Es relevante para evaluar la relación entre experiencia laboral y progresión profesional.</p>
#     </li>
#     <li><strong>Education Level (Nivel educativo):</strong>
#         <p>Tipo: Categórica (String)</p>
#         <p>Descripción: El nivel más alto de educación alcanzado por el individuo.</p>
#         <p>Importancia: Es clave para comprender cómo los niveles educativos afectan la empleabilidad, los ingresos y por consecuencia al cambio de especialidad u ocupación.</p>
#     </li>
#     <li><strong>Industry Growth Rate (Tasa de crecimiento de la industria):</strong>
#         <p>Tipo: Categórica (String)</p>
#         <p>Descripción: La tasa de crecimiento de la industria donde trabaja el individuo.</p>
#         <p>Importancia: Ayuda a identificar oportunidades laborales en sectores en expansión.</p>
#     </li>
#     <li><strong>Job Satisfaction (Satisfacción laboral):</strong>
#         <p>Tipo: Entero (Escala 1-10)</p>
#         <p>Descripción: Calificación de la satisfacción laboral del individuo.</p>
#         <p>Importancia: Permite medir la felicidad y motivación en el trabajo, influenciando la productividad.</p>
#     </li>
#     <li><strong>Work-Life Balance (Equilibrio trabajo-vida):</strong>
#         <p>Tipo: Entero (Escala 1-10)</p>
#         <p>Descripción: Calificación del equilibrio percibido entre trabajo y vida personal.</p>
#         <p>Importancia: Es un indicador del bienestar laboral y personal.</p>
#     </li>
#     <li><strong>Job Opportunities (Oportunidades laborales):</strong>
#         <p>Tipo: Entero</p>
#         <p>Descripción: Número de oportunidades laborales disponibles en el campo del individuo.</p>
#         <p>Importancia: Ayuda a analizar la demanda en ciertos campos ocupacionales.</p>
#     </li>
#     <li><strong>Salary (Salario):</strong>
#         <p>Tipo: Entero</p>
#         <p>Descripción: El salario anual del individuo (en USD o moneda local equivalente).</p>
#         <p>Importancia: Es crucial para evaluar la relación entre estudios, ocupación e ingresos.</p>
#     </li>
#     <li><strong>Job Security (Seguridad laboral):</strong>
#         <p>Tipo: Entero (Escala 1-10)</p>
#         <p>Descripción: Calificación de la seguridad laboral percibida por el individuo.</p>
#         <p>Importancia: Influye en la estabilidad y satisfacción laboral del individuo.</p>
#     </li>
#     <li><strong>Skills Gap (Brecha de habilidades):</strong>
#         <p>Tipo: Entero (Escala 1-10)</p>
#         <p>Descripción: Una medida de cuán bien se ajustan las habilidades actuales del individuo a los requisitos de su trabajo.</p>
#         <p>Importancia: Es fundamental para identificar necesidades de capacitación.</p>
#     </li>
#     <li><strong>Family Influence (Influencia Familiar):</strong>
#         <p>Tipo:</p> Categórica (String)
#         <p>Descripción:</p> El grado de influencia que tiene la familia de la persona en la elección de su carrera.
#         <p>Importancia: Demuestra la incidencia que puede tener el núcleo familiar en la vida de la persona</p>
#   </li>
#   <li><strong>Mentorship Available (Mentoría Disponible):</strong>
#         <p>Tipo: Entero (0 o 1)</p>
#         <p>Descripción: Indica si la persona tiene acceso a un mentor en su trabajo actual.</p>
#         <p>Importancia: Determina si la persona tenia o tiene alguien que lo haya guiado a la hora de realizar sus activades en su empleo, esto es determinante a la hora de cualificar la dificualtad del trabajo</p>
#   </li>
#   <li><strong>Certifications (Certificaciones):</strong>
#         <p>Tipo: Entero (0 o 1)</p>
#         <p>Descripción: Indica si la persona posee certificaciones relevantes para su ocupación.</p>
#         <p>Importancia: Mide si la persona esta cualificada formalmente para su puesto de trabajo, esto evita que su desempeño se eclipsado por la falta de la certificación</p>
#   </li>
#   <li><strong>Freelancing Experience (Experiencia en trabajo en línea):</strong>
#         <p>Tipo: Entero (0 o 1)</p>
#         <p>Descripción: Indica si la persona ha trabajado como freelancer en el pasado.</p>
#         <p>Importancia: Ayuda analizar si el encuestado ha trabajado en línea alguna vez</p>
#   </li>
#   <li><strong>Geographic Mobility (Movilidad Geográfica):</strong>
#         <p>Tipo: Entero (0 o 1)</p>
#         <p>Descripción: Indica si la persona está dispuesta a mudarse por un trabajo.</p>
#         <p>Importancia: La capacidad de movilizarce a otro país en busca del trabajo deseado es una variable importante que puede hacer que una persona tome un trabajo aunque este no le guste</p>
#   </li>
#   <li><strong>Professional Networks (Redes Profesionales):</strong>
#         <p>Tipo: Entero (escala 1-10)</p>
#         <p>Descripción: Una medida de la fortaleza de la red profesional de la persona.</p>
#         <p>Importacia: Las relaciones laborales son clave para el avance de cualquier carrera profesional puesto que estas pueden impulsar a las personas a mejores oportunidades</p>
#   </li>
#   <li><strong>Career Change Events (Eventos de Cambio de Carrera):</strong>
#         <p>Tipo: Entero </p>
#         <p>Descripción: El número de cambios de carrera realizados por la persona en el pasado.</p>
#         <p>Importancia: Esto permite determinar si la persona tiene la tendencia a cambiar de carrera</p>
#   </li>
#   <li><strong>Technology Adoption (Adopción de Tecnología):</strong><br>
#         <p>Tipo: Entero (escala 1-10)</p>
#         <p>Descripción:Una medida del nivel de comodidad de la persona con la adopción de nuevas tecnologías.</p>
#         <p>Importancia: Esta variable es clave para el cambio de carrera ya que si la persona no esta abierta al cambio es menos problable que desee un cambio</p>
#   </li>
#   <li><strong>Likely to Change Occupation (Probabilidad de Cambiar de Ocupación):</strong>
#         <p>Tipo: Entero (0 o 1)</p>
#         <p>Descripción:Variable objetivo que indica si es probable que la persona cambie de ocupación.</p>
#         <p>Importancia: Es la variable objetivo la cual sera evaluada para realizar el estudio</p>
#   </li>
# </ul>
#     </br></br>
# </div>

# %%
import pandas as pd

dataset = pd.read_csv("career_change_prediction_dataset.csv")
dataset.head(5)
# Out:
#   Field of Study Current Occupation  Age  Gender  Years of Experience  \
# 0       Medicine   Business Analyst   48    Male                    7
# 1      Education          Economist   44    Male                   26
# 2      Education          Biologist   21  Female                   27
# 3      Education   Business Analyst   33    Male                   14
# 4           Arts             Doctor   28  Female                    0
#
#   Education Level Industry Growth Rate  Job Satisfaction  Work-Life Balance  \
# 0     High School                 High                 7                 10
# 1        Master's                  Low                10                  3
# 2        Master's                  Low                 8                  3
# 3             PhD               Medium                 7                  9
# 4             PhD                  Low                 3                  1
#
#    Job Opportunities  ...  Skills Gap  Family Influence  Mentorship Available  \
# ...

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div>
#     <p class= "titulo2" align="center">5. Analisis demográfico de los datos </p>
#     </br>
#  </div>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">Para la descripción de los datos haremos histogramas usando la siguiente función que utiliza matplotlib para realizar dichos gráficos, con los datos ya en gráficos se hará un analisis de cada uno de ellos por separado para llegar a una conclusión</p></br>

# %%
import matplotlib.pyplot as plt
def plot_column(col1:str, col2:str, name:str, xlabel:str, ylabel:str, size:tuple):
    # Obtener las frecuencias para cada categoría
    field_counts = dataset.groupby([col1, col2], observed=True).size().unstack()
    total_counts = field_counts.sum(axis=1)
    # Calcular los porcentajes para cada categoría respecto al total del dataset
    total_dataset = total_counts.sum()
    category_percentages = (total_counts / total_dataset) * 100
    # Calcular los porcentajes
    field_percentages = field_counts.div(field_counts.sum(axis=1), axis=0) * 100

    # Crear el gráfico de barras
    ax = field_percentages.plot(kind='bar', figsize=size, edgecolor="blue", linewidth=0.7)

    # Agregar los porcentajes encima de cada barra
    for container in ax.containers:
        # Para cada barra en el contenedor
        ax.bar_label(container, fmt='%.1f%%', label_type='edge')  # %.1f%% para mostrar porcentajes con un decimal
    
    # Agregar los porcentajes debajo de cada categoría en el eje X
    total_counts.reset_index(drop=True, inplace=True)
    for i, percentage in enumerate(category_percentages):
        ax.text(
            i, -5,  # Posición X (índice de la barra) y Y (debajo del eje X)
            f'{percentage:.1f}%\n {total_counts.loc[i]}',  # Texto del porcentaje
            ha='center', va='center', fontsize=10, color='black'
        )

    # Etiquetas y título
    plt.title(name)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=90)  # Girar las etiquetas del eje X para mejor legibilidad
    plt.yticks(rotation=90)  # Girar las etiquetas del eje X para mejor legibilidad
    plt.ylim(-10, 100) 
    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
#
# <strong> <p class="subtitulo2">5.1 Field of study </p> </strong>

# %%
plot_column(
    'Field of Study',
    'Likely to Change Occupation', 
    'Histograma Campo de estudio', 
    'profesiones', 
    'cambio de especialidad',
    (12,10))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
#
# <p class= "subtitulo2">Los campos de estudio constituyen las carreras las cuales son ofertadas en los centros de educación superior, en este set de datos se encuentran 10 carreras distintas las cuales son las observadas en este gráfico donde estas están relacionadas con la tasa de cambio de ocupación en cada una de ellas.
# </br>
# </br>
# Es observable que medicina es por lejos el campo con una mayor tasa de cambio de ocupación con 19.4%, siguiendo ingeniería  mecánica  con un 17.7% y leyes con un 16.2%, esto podría reflejar que estas carreras presentan un índice dificultad mayor a la media, empleabilidad baja o son mal remuneradas por lo que es evidente que hay una cierta parte de estos profesionales que está abierto a la posibilidad de realizar un cambio y dejar su puesto, pero esto también puede correlacionarse con otros factores.
# </br>
# </br>
#  Puesto que a diferencia de los campos en humanidades como lo es psicología (13.4%) o negocios (14%) podemos ver que hay una tasa de cambio menor a que las carreras más técnicas, lo que podría indicar que estas presentan una mejor estabilidad laboral o el trabajo es mejor remunerado.
#  </br>
#  </br>
#  Un punto interesante es que Ciencias de la Computación presenta la tasa de cambio más baja. Esto podría sugerir que este campo ofrece mayores oportunidades laborales, estabilidad y competitividad salarial, reflejando la alta demanda de habilidades tecnológicas en el mercado actual. Sin embargo, es importante considerar factores adicionales, como los ingresos promedio y las tasas de desempleo, para entender completamente estas tendencias.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.2 Current ocupation </p> </strong></div>

# %%
plot_column(
    'Current Occupation',
    'Likely to Change Occupation', 
    'Histograma de Ocupaciones', 
    'profesiones', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">Por el contrario del campo de estudio en la ocupación actual no hay tendencias tan evidentes de cambio lo que demuestra que la ocupación actual no es determinante en la decisión del individuo para el cambio de especialidad o carrera, esto significa que los factores que afectan mayor a esta decisión puede ser la familia, el mercado laboral, el balance entre la vida laboral y vida personal o tal vez la dificultad de la misma carrera.</br></br>
# Este gráfico nos muestra que las ocupaciones con el mayor tendencia al cambio son los Doctores y biologos con un 17.3%, siguiendo los abogados con un 16.4%. Mientras que los que tienen mayor estabilidad son los psicólogos con un 13.8% y los desarrolladores de software con un 13.6%
# </p></br>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.3 Age </p> </strong></div>

# %%
# Calcular los intervalos de clase porque son datos continuos
bins = [20 + i * 3 for i in range(14)]  # 14 bordes para 15 intervalos
labels = [f'{int(bins[i])}-{int(bins[i+1]-1)}' for i in range(len(bins)-1)]
# Crear los intervalos en el dataset
dataset['Age Range'] = pd.cut(dataset['Age'], bins=bins, labels=labels, include_lowest=True)

# %%
plot_column(
    'Age Range',
    'Likely to Change Occupation', 
    'Histograma Edades', 
    'Edades', 
    'cambio de especialidad',
    (20,20))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">Sabemos que la edad es el tiempo que transcurre desde el nacimiento del ser humano y es la unidad que permite dividir la vida humana en distintas etapas, la vida laboral inicia a partir de los 20 años aproximadamente, este gráfico muestra un rango de edad de 20 años a 59 años  el cual expresa que el pico más alto de tasa de cambio es el de la edad de 23 años con 22.2%, mientras que aquellos profesional con más experiencia y mayor edad presentan mayor estabilidad siendo 51 años el valle más bajo con un 10.4%. </br></br>
# Esto demuestra que los jóvenes (20-30) tienen una mayor volatilidad donde más de 50% está abierto a un cambio (específicamente un 58.60%), en la mediana edad (31-45) hay una cierta estabilidad moderada con 57% abierto al cambio, lo cual se mantiene en los mayores a 46 años aunque solo el 56% está abierto a un cambio de ocupación.</br></br>
# Esto demuestra que no existe un límite de tiempo para un cambio, es decir, no es un factor determinante para la elección del cambio de ocupación, sin embargo, hay una clara tendencia en los grupos etarios más jóvenes son un más abiertos a un cambio, esto puede ser causado por diversos factores, buscando mejores ofertas laborales, un mejor balance entre la vida personal y el trabajo o en busca de nuevas experiencias que potencien sus habilidades.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.4 Gender </p> </strong></div>

# %%
plot_column(
    'Gender',
    'Likely to Change Occupation', 
    'Histograma Género', 
    'Género', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">Como es observable en el gráfico hay una paridad en los datos con una diferencia máxima de 0.3 puntos porcentuales, lo que indica el cambio de ocupación es independiente del género, aunque parece que hay una pequeña tendencia en el género masculino en estar más dispuesto a un cambio, pero es  una diferencia de sólo 0.3% por lo que no es determinante. Posiblemente esto es debido a las nuevas políticas de igualdad de género lo que ha permitido balancear las oportunidades del mercado laboral ofreciendo un terreno neutral para ambos géneros de manera que no afecte esto a su carrera profesional.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.5 Years of experiencies </p> </strong></div>

# %%
# Calcular los intervalos de clase porque son datos continuos
bins = [0 + i * 3 for i in range(14)]  # 14 bordes para 13 intervalos
labels = [f'{int(bins[i])}-{int(bins[i+1]-1)}' for i in range(len(bins)-1)]
# Crear los intervalos en el dataset
dataset['Years of Experience Range'] = pd.cut(dataset['Years of Experience'], bins=bins, labels=labels, include_lowest=True)

# %%
plot_column(
    'Years of Experience Range',
    'Likely to Change Occupation', 
    'Histograma Años de experiencia', 
    'Años de experiencia', 
    'cambio de especialidad',
    (20,20))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">La distribución de años de experiencia (rango de 0 a 39 años) y su relación con la probabilidad de cambio ocupacional indica que la movilidad ocupacional es más alta en los primeros años de la carrera profesional y alcanza su pico máximo en los 15 años de experiencia, con una tasa de cambio del 22.3%.</br></br>
# Esto podría deberse a la búsqueda de mejores oportunidades, ajustes iniciales en la carrera o insatisfacción temprana en el empleo. A partir de los 10 años, se detecta una estabilización en las tasas de cambio, lo que podría estar asociado a mayor especialización, estabilidad financiera o vínculos más sólidos con las organizaciones. Finalmente, la correlación inversa entre experiencia y cambio ocupacional sugiere que los empleados con más años en el mercado laboral tienden a priorizar la estabilidad laboral.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.6 Education Level</p> </strong></div>

# %%
plot_column(
    'Education Level',
    'Likely to Change Occupation', 
    'Histograma Nivel de educación', 
    'profesiones', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">El análisis revela que el nivel educativo no tiene un impacto significativo en la probabilidad de cambio ocupacional.</br></br>
# El rango de probabilidad de cambio ocupacional es estrecho, oscilando entre 57.2% y 58.1%. Los patrones principales son los individuos con nivel Master's, con un 58.1% de cambio ocupacional. Mientras que los individuos con nivel PhD, con un 57.2%.</br></br>
# La diferencia máxima entre los niveles (0.9 puntos porcentuales) es demasiado pequeña para considerar que el nivel educativo sea un factor determinante en la movilidad laboral. Además, la distribución uniforme de la muestra fortalece la validez de estas conclusiones, ya que asegura una representación equilibrada de cada nivel educativo.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.7 Industry Growth Rate</p> </strong></div>

# %%
plot_column(
    'Industry Growth Rate',
    'Likely to Change Occupation', 
    'Histograma Tasa de crecimiento de la industria en la profesión estudiada', 
    'Tasa de crecimiento', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">La tasa de crecimiento de la industria parece no ser un factor determinante en la decisión de cambiar de especialidad, ya que las variaciones entre los grupos son pequeñas. <br><br>
# Puesto que en términos de crecimiento industrial, la tasa de cambio de especialidad no presenta diferencias marcadas, ya que todos los grupos se mueven en un rango estrecho de 57.0% a 58.4%.
# El grupo Medium tiene el mayor porcentaje de cambio, mientras que el grupo High registra el menor. <br><br>
# Sin embargo, es interesante notar que la categoría Medium tiene la mayor proporción de cambios, lo que podría estar relacionado con un equilibrio en oportunidades y estabilidad laboral en estas industrias.<br><br>
# Las industrias con alta tasa de crecimiento (High) no necesariamente garantizan menor movilidad, ya que los porcentajes de cambio siguen siendo similares a las demás categorías.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.8 Job Satisfaction</p> </strong></div>

# %%
plot_column(
    'Job Satisfaction',
    'Likely to Change Occupation', 
    'Histograma Satisfacción laboral', 
    'Tasa de Satisfacción', 
    'cambio de especialidad',
    (15,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">El gráfico ilustra la relación entre la tasa de satisfacción laboral (en una escala de 1 a 10) y la probabilidad de cambio de especialidad. Los datos incluyen aproximadamente 3,800 individuos por nivel de satisfacción.
# Para los niveles de satisfacción 1 a 4, el 100% de los encuestados están propensos a cambiar de especialidad, mostrando insatisfacción total con su situación actual. <br><br>
# Para los niveles de satisfacción 5 a 10, la probabilidad de cambio disminuye significativamente, oscilando entre el 28.5% y el 30.8%, con una mayoría permaneciendo en su especialidad.
# Existe una relación inversa clara entre satisfacción laboral y probabilidad de cambio de especialidad: a menor satisfacción, mayor propensión a cambiar.<br><br>
# El cambio del 100% en los niveles bajos de satisfacción a aproximadamente 30% en los niveles altos subraya la importancia de la satisfacción laboral como factor determinante para la permanencia en la especialidad.
# Los niveles más altos de satisfacción (9 y 10) aún presentan un cambio cercano al 30%, lo que podría deberse a otros factores como ambiciones personales o búsqueda de mejores oportunidades.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.9 Work-Life Balance</p> </strong></div>

# %%
plot_column(
    'Work-Life Balance',
    'Likely to Change Occupation', 
    'Histograma Balance entre la vida personal y la vida laboral', 
    'Tasa de balance', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">Para todas las tasas de balance (de 1 a 10), se observa que la proporción de cambio de especialidad es mayor al 56%, mientras que aquellos que deciden permanecer representan alrededor del 40%. Específicamente, en el nivel más bajo de balance (1), un 56.9% está dispuesto a cambiar frente a un 43.1% que permanece. </br></br> A medida que mejora el balance, los valores se mantienen relativamente consistentes, con un leve aumento en la probabilidad de cambio en niveles más altos como el 10, donde 58.8% cambia y 41.2% permanece. Este patrón refleja que incluso con niveles altos de balance entre vida personal y laboral, una proporción considerable de personas considera cambiar de especialidad, sugiriendo que factores externos como oportunidades laborales o crecimiento profesional podrían influir en la decisión. </br></br> Esto subraya la importancia de analizar no solo el balance trabajo-vida, sino también otros aspectos contextuales que afectan la satisfacción profesional.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.10 Job Opportunities</p> </strong></div>

# %%
# Calcular los intervalos de clase porque son datos continuos
bins = [0 + i * 7.69 for i in range(14)]  # 14 bordes para 13 intervalos
labels = [f'{int(bins[i])}-{int(bins[i+1]-1)}' for i in range(len(bins)-1)]
# Crear los intervalos en el dataset
dataset['Job Opportunities Range'] = pd.cut(dataset['Job Opportunities'], bins=bins, labels=labels, include_lowest=True)

# %%
plot_column(
    'Job Opportunities Range',
    'Likely to Change Occupation', 
    'Histograma Oportunidades de empleo', 
    'Oportunidades', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">El gráfico revela patrones significativos en la demanda ocupacional. El gráfico presenta una escala de 0-100 oportunidades por campo, con una distribución que muestra considerable variabilidad entre sectores. Los datos indican un promedio de 3-4 oportunidades por campo, con picos notables que superan las 5 oportunidades en algunos sectores específicos, mientras otros muestran una demanda más limitada con menos de 2 oportunidades.
# </br></br>
# Es interesante observar que la mayor disponibilidad de oportunidades no siempre se correlaciona directamente con una mayor tasa de cambio ocupacional, sugiriendo que otros factores influyen en la decisión de cambio laboral. Los sectores tradicionales muestran una mayor estabilidad en comparación con los mercados emergentes, que presentan mayor volatilidad.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.11 Salary</p> </strong></div>

# %%
# Calcular los intervalos de clase porque son datos continuos
bins = [30000 + i * 10625 for i in range(14)]  # 17 bordes para 16 intervalos
labels = [f'{int(bins[i])}-{int(bins[i+1]-1)}' for i in range(len(bins)-1)]
# Crear los intervalos en el dataset
dataset['Salary Range'] = pd.cut(dataset['Salary'], bins=bins, labels=labels, include_lowest=True)

# %%
plot_column(
    'Salary Range',
    'Likely to Change Occupation', 
    'Histograma Salarios', 
    'Salarios', 
    'cambio de especialidad',
    (20,20))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">El histograma de salarios muestra una tendencia reveladora en la relación entre los niveles salariales y la probabilidad de cambio ocupacional. En los rangos salariales más bajos (30000-40624), se observa una disparidad dramática con una probabilidad de cambio del 100%, mientras que en el siguiente rango (40625-51249) esta probabilidad disminuye levemente al 94.4%. </br></br>
# A partir de los rangos salariales medios (51250 en adelante), la distribución se estabiliza significativamente, mostrando una proporción más equilibrada entre quienes permanecen y quienes cambian de ocupación, con probabilidades que oscilan entre 50-54%. </br></br>
# Es notable que a medida que aumenta el salario, la tendencia al cambio ocupacional se reduce y se estabiliza, sugiriendo que la compensación económica juega un papel crucial en la retención de talento. Los datos también revelan que el tamaño de la muestra es consistente a lo largo de los rangos salariales (aproximadamente 2300-2500 individuos por rango), lo que fortalece la validez de estas observaciones y sugiere que las estrategias de retención basadas en compensación podrían ser más efectivas en los rangos salariales más bajos.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.12 Job Security</p> </strong></div>

# %%
plot_column(
    'Job Security',
    'Likely to Change Occupation', 
    'Histograma Seguridad laboral', 
    'Seguridad', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">Los datos muestran una variación moderada pero consistente, con un rango de probabilidad de cambio que oscila entre 56.5% y 59.3%. El punto más alto de propensión al cambio se observa en el nivel 5 de seguridad (59.3%), mientras que el punto más bajo se encuentra en el nivel 8 (56.5%).</br></br>
#  Es notable que la muestra está distribuida de manera uniforme a través de todos los niveles de seguridad, con aproximadamente 3,800 individuos por nivel, lo que proporciona solidez estadística a los resultados.</br></br>
# Curiosamente, incluso en los niveles más altos de seguridad laboral (9-10), la propensión al cambio se mantiene por encima del 56%, sugiriendo que la seguridad laboral por sí sola no es un factor determinante en la decisión de cambiar de ocupación, y que otros factores podrían tener una influencia más significativa en esta decisión.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.13 Skills Gap</p> </strong></div>

# %%
plot_column(
    'Skills Gap',
    'Likely to Change Occupation', 
    'Histograma Brecha de habilidades', 
    'Brecha', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">Los datos revelan una tendencia relativamente consistente, con una probabilidad de cambio que varía entre 56.1% y 59.1%. El punto más alto de propensión al cambio se encuentra en el nivel 9 (59.1%), mientras que el nivel más bajo se observa en el nivel 10 (56.1%).</br></br>
# Es interesante notar que incluso cuando la brecha de habilidades es menor (niveles 1-2), la propensión al cambio se mantiene por encima del 56%, sugiriendo que la brecha de habilidades no es necesariamente un factor determinante en la decisión de cambiar de ocupación, y que podrían existir otros elementos más influyentes en esta decisión.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.14 Family Influence</p> </strong></div>

# %%
plot_column(
    'Family Influence',
    'Likely to Change Occupation', 
    'Histograma Influencia familiar', 
    'Influencia', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">En todos los niveles de influencia, se observa una mayor proporción de individuos con probabilidad de cambio (valor 1), representando aproximadamente entre 56.5% y 58.1% de cada grupo, mientras que aquellos menos propensos al cambio (valor 0) constituyen entre 41.9% y 43.5%.
# </br></br>
# La diferencia más notable se encuentra en el nivel "High" de influencia, donde el 58.1% muestra propensión al cambio, seguido por el nivel "Medium" con 57.7% y "Low" con 56.5%, sugiriendo que la influencia familiar podría tener un efecto moderadamente positivo en la probabilidad de cambio ocupacional, aunque las diferencias entre niveles son relativamente pequeñas.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.15 Mentorship Available</p> </strong></div>

# %%
plot_column(
    'Mentorship Available',
    'Likely to Change Occupation', 
    'Histograma Interes en cambiar de carrera', 
    'Mentoria', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">El gráfico muestra la relación entre el mentoria disponible en cambiar de carrera y la probabilidad de cambio ocupacional. Se observa que el mentoria disponible en cambiar de carrera (valor 1) tiene una tasa de cambio ocupacional significativamente más alta que aquellos sin mentoria disponible (valor 0). Específicamente, aquellos con mentoria disponible en cambiar de carrera tienen una tasa de cambio de 57.8%, mientras que los que no tienen mentoria disponible presentan una tasa de cambio de 42.2%. Además, la cantidad de personas con mentoria disponible en cambiar de carrera es de 11,531 individuos, mientras que los que no tienen mentoria disponible suman 26,913.
#
# Esto sugiere que el mentoria disponible en cambiar de carrera está fuertemente relacionado con una mayor propensión a cambiar de ocupación, lo que indica que las personas con deseos de cambiar su campo de trabajo tienen una mayor disposición a explorar nuevas oportunidades laborales. Sin embargo, la diferencia de tasas entre estos dos grupos también refleja la estabilidad que caracteriza a los individuos sin mentoria disponible en cambiar, quienes pueden sentirse más satisfechos o cómodos con sus posiciones actuales. Este patrón refuerza la importancia de comprender las motivaciones personales al evaluar las dinámicas de cambio ocupacional, lo que podría ser útil para diseñar estrategias de retención o de desarrollo de talento en diversas áreas profesionales.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.16 Certifications</p> </strong></div>

# %%
plot_column(
    'Certifications',
    'Likely to Change Occupation', 
    'Histograma Certificaciones necesarias', 
    'Certificaciones', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">Es observable que más del 70% de los datos alojados en el dataset afirma que no posee las certificaciones necesarias para ejercer su campo de estudio en el cual tenemos que 57.6% esta abierto a un cambio, esto puede implicar que el número de certificaciones no forma parte de uno de los factores que provocan el cambio de profesión una vez estudiada </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.17 Freelancing Experience</p> </strong></div>

# %%
plot_column(
    'Freelancing Experience',
    'Likely to Change Occupation', 
    'Histograma Freelancing Experience', 
    'Experiencia', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">El gráfico revela una distribución asimétrica en la muestra, con 26,913 casos (70%) para el nivel de experiencia  0 y 11,531 casos (30%) para el nivel de experiencia 1. </br></br>
#  En ambos niveles de experiencia, se observa una tendencia similar en la probabilidad de cambio ocupacional, donde aproximadamente el 57-58% de los individuos muestran propensión al cambio (valor 1), mientras que alrededor del 42-43% se muestran menos propensos (valor 0). </br></br>
# Específicamente, en el nivel de experiencia  0, el 57.7% muestra propensión al cambio, mientras que en el nivel de experiencia 1, esta proporción es del 57.3%, sugiriendo que la experiencia en freelancing  tiene una influencia marginalmente pequeña en la probabilidad real de cambio ocupacional.
# </p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.18 Geographic Mobility</p> </strong></div>

# %%
plot_column(
    'Geographic Mobility',
    'Likely to Change Occupation', 
    'Histograma Movilidad Geografica', 
    'Movilidad', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">La muestra total de 38,444 casos se distribuye asimétricamente con 26,758 casos (69.6%) en movilidad 0 y 11,686 casos (30.4%) en movilidad 1. Los patrones de probabilidad de cambio son casi idénticos entre ambos niveles, con 57.7% y 57.6% mostrando propensión al cambio (valor 1) para los niveles 0 y 1 respectivamente, mientras que 42.3% y 42.4% muestran menor propensión (valor 0), indicando que la movilidad geográfica tiene un impacto mínimo en la probabilidad de cambio ocupacional.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.19 Professional Networks</p> </strong></div>

# %%
plot_column(
    'Professional Networks',
    'Likely to Change Occupation', 
    'Histograma Red profesional', 
    'Redes', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">La propensión al cambio (valor 1) oscila entre 56.4% y 59.6%, con el pico más alto en el nivel 7 (59.6%) y el más bajo en el nivel 2 (56.4%). Los menos propensos al cambio (valor 0) varían entre 40.4% y 43.6%, mostrando que el nivel de red profesional tiene un impacto modesto en la probabilidad de cambio ocupacional, lo que quiere decir que hay otros factores externos que están determinando el cambio como lo puede ser la edad, el mercado laboral o los salarios.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.20 Career Change Events</p> </strong></div>

# %%
plot_column(
    'Career Change Events',
    'Likely to Change Occupation', 
    'Histograma Eventos de cambio de carrera', 
    'Nro° de cambios', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2">La propensión al cambio ocupacional (valor 1) varía ligeramente entre 57.3% y 58.0%, siendo más alta en el nivel 2 (58.0%) y más baja en el nivel 1 (57.3%), mientras que los menos propensos al cambio (valor 0) oscilan entre 42.0% y 42.7%, sugiriendo que el número de eventos de cambio de carrera tiene un impacto mínimo en la probabilidad de cambio ocupacional, dando a respuesta que independientemente de los cambios que realicen los profesionales estos siempre estarán abiertos a un cambio de carrera.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div align="center" >
# <strong> <p class="subtitulo2">5.21 Technology Adoption</p> </strong></div>

# %%
plot_column(
    'Technology Adoption',
    'Likely to Change Occupation', 
    'Histograma Adopción de la tecnologia', 
    'Tasa de adopción', 
    'cambio de especialidad',
    (10,6))

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <p class="subtitulo2"> La tendencia hacia el cambio ocupacional (valor 1) oscila entre el 56.3% y el 58.8%, alcanzando su punto más alto en el nivel 7 (58.8%) y el más bajo en el nivel 8 (56.3%). Por otro lado, los individuos menos propensos al cambio (valor 0) se sitúan entre el 41.2% y el 43.7%. Esto sugiere que la tasa de adopción tecnológica tiene una influencia moderada en la probabilidad de cambio ocupacional. Algunas posibles causas de este comportamiento podrían incluir que niveles más altos de adopción tecnológica estén vinculados a una mayor percepción de oportunidades en nuevos roles o sectores, mientras que niveles más bajos reflejan una resistencia al cambio debido a la falta de habilidades técnicas avanzadas o incertidumbre en la transición a tecnologías emergentes.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div>
#     <p class= "titulo2" align="center">6. Conclusiones </p>
#     </br>
#  </div>
#
#  <p>El análisis exploratorio de datos realizado revela factores clave que influyen en el cambio ocupacional, destacando la importancia de diversas variables como la satisfacción laboral, el balance entre vida personal y laboral, y la adopción tecnológica. La satisfacción laboral muestra una relación directa con la propensión al cambio, siendo los niveles más bajos de satisfacción los que presentan una mayor probabilidad de cambiar de ocupación. Por su parte, el balance entre vida personal y laboral tiene un impacto significativo, ya que las personas con un balance percibido como bajo tienden a cambiar de especialidad con mayor frecuencia. Finalmente, la adopción tecnológica, aunque con un efecto más modesto, también incide en la propensión al cambio, especialmente en niveles específicos de adopción.
#     </br>
#     </br>
#
# Estos hallazgos sugieren que el sistema de selección para estudios superiores podría beneficiarse de un enfoque más integral que considere estas variables en la orientación vocacional y profesional. Identificar las necesidades individuales y garantizar una mejor alineación entre los campos de estudio, las habilidades requeridas en el mercado laboral y las expectativas personales puede reducir la probabilidad de cambios ocupacionales, optimizando así las oportunidades educativas.</p>

# %% [markdown]
# <head>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <div>
#     <p class= "titulo2" align="center">7. ¿Como predecir el cambio? </p>
#     </br>
#  </div>
#
#  <p>
#     </br>
#     </br>
# </p>

# %%
import pandas as pd
dt = pd.read_csv('career_change_prediction_dataset.csv')

# %%
# Buscando los valores unicos de la columna 1
for i in dt['Field of Study'].unique(): print(i)
# Out:
# Medicine
# Education
# Arts
# Computer Science
# Business
# Mechanical Engineering
# Biology
# Law
# Economics
# Psychology

# %% [markdown]
# <div align="center">
# <table border="1">
#     <tr>
#         <th>Field of study</th>
#         <th>Numeric Value</th>
#     </tr>
#     <tr>
#         <td>Medicine</td>
#         <td>0</td>
#     </tr>
#     <tr>
#         <td>Education</td>
#         <td>1</td>
#     </tr>
#     <tr>
#         <td>Arts</td>
#         <td>2</td>
#     </tr>
#     <tr>
#         <td>Computer Science</td>
#         <td>3</td>
#     </tr>
#     <tr>
#         <td>Business</td>
#         <td>4</td>
#     </tr>
#     <tr>
#         <td>Mechanical Engineering</td>
#         <td>5</td>
#     </tr>
#     <tr>
#         <td>Biology</td>
#         <td>6</td>
#     </tr>
#     <tr>
#         <td>Law</td>
#         <td>7</td>
#     </tr>
#     <tr>
#         <td>Economics</td>
#         <td>8</td>
#     </tr>
#     <tr>
#         <td>Psychology</td>
#         <td>9</td>
#     </tr>
# </table>
# </div>

# %%
# Convirtiendo los valores en datos númericos
careers = {
    "Medicine":0,
    "Education":1,
    "Arts":2,
    "Computer Science":3,
    "Business":4,
    "Mechanical Engineering":5,
    "Biology":6,
    "Law":7,
    "Economics":8,
    "Psychology":9,
}
# Sustituimos por los valores de la tabla 
dt['Field of Study'] = dt['Field of Study'].map(careers)

# %%
for i in dt['Current Occupation'].unique(): print(i)
# Out:
# Business Analyst
# Economist
# Biologist
# Doctor
# Lawyer
# Software Developer
# Artist
# Psychologist
# Teacher
# Mechanical Engineer

# %% [markdown]
# <div align="center">
#     <table border="1">
#     <tr>
#         <th>Ocupación</th>
#         <th>Valor Numérico</th>
#     </tr>
#     <tr><td>Business Analyst</td><td>0</td></tr>
#     <tr><td>Economist</td><td>1</td></tr>
#     <tr><td>Biologist</td><td>2</td></tr>
#     <tr><td>Doctor</td><td>3</td></tr>
#     <tr><td>Lawyer</td><td>4</td></tr>
#     <tr><td>Software Developer</td><td>5</td></tr>
#     <tr><td>Artist</td><td>6</td></tr>
#     <tr><td>Psychologist</td><td>7</td></tr>
#     <tr><td>Teacher</td><td>8</td></tr>
#     <tr><td>Mechanical Engineer</td><td>9</td></tr>
# </table>
#
# </div>

# %%
occupation_mapping = {
    "Business Analyst": 0,
    "Economist": 1,
    "Biologist": 2,
    "Doctor": 3,
    "Lawyer": 4,
    "Software Developer": 5,
    "Artist": 6,
    "Psychologist": 7,
    "Teacher": 8,
    "Mechanical Engineer": 9
}
dt['Current Occupation'] = dt['Current Occupation'].map(occupation_mapping)

# %%
dt['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# <div align="center">
#     <table border="1">
#     <tr>
#         <th>Genero</th>
#         <th>Valor Numérico</th>
#     </tr>
#     <tr><td>Male</td><td>0</td></tr>
#     <tr><td>Female</td><td>1</td></tr>
# </table>
#
# </div>

# %%
gender_mapping = {
    'Male':0,
    'Female':1,
}
dt['Gender'] = dt['Gender'].map(gender_mapping)

# %%
dt['Education Level'].unique()
# Out:
# array(['High School', "Master's", 'PhD', "Bachelor's"], dtype=object)

# %% [markdown]
# <div align="center">
#     <table border="1">
#     <tr>
#         <th>Nivel de educación</th>
#         <th>Valor Numérico</th>
#     </tr>
#     <tr><td>High School</td><td>0</td></tr>
#     <tr><td>Master's</td><td>1</td></tr>
#     <tr><td>PhD</td><td>2</td></tr>
#     <tr><td>Bachelor's</td><td>3</td></tr>
# </table>
#
# </div>

# %%
education_mapping = {
    'High School': 0,
    "Master's": 1,
    'PhD': 2,
    "Bachelor's": 3
}
dt['Education Level'] = dt['Education Level'].map(education_mapping)

# %%
dt['Industry Growth Rate'].unique()
# Out:
# array(['High', 'Low', 'Medium'], dtype=object)

# %% [markdown]
# <div align="center">
#     <table border="1">
#     <tr>
#         <th>Tasa de crecimiento en la industria</th>
#         <th>Valor Numérico</th>
#     </tr>
#     <tr><td>High</td><td>0</td></tr>
#     <tr><td>Low</td><td>1</td></tr>
#     <tr><td>Medium</td><td>2</td></tr>
# </table>
#
# </div>

# %%
industry_mapping = {
    "High": 0,
    "Low":1,
    "Medium":2
}
dt['Industry Growth Rate'] = dt['Industry Growth Rate'].map(industry_mapping)

# %%
dt['Family Influence'] = dt['Family Influence'].fillna('Other')
dt['Family Influence'].unique()
# Out:
# array(['High', 'Medium', 'Low', 'Other'], dtype=object)

# %% [markdown]
# <div align="center">
#     <table border="1">
#     <tr>
#         <th>Influencia de la familia</th>
#         <th>Valor Numérico</th>
#     </tr>
#     <tr><td>High</td><td>0</td></tr>
#     <tr><td>Medium</td><td>1</td></tr>
#     <tr><td>Low</td><td>2</td></tr>
#     <tr><td>Other</td><td>3</td></tr>
# </table>
#
# </div>

# %%
family_influence = {
    'High':0,
    'Medium':1,
    'Low':2,
    'Other':3
}
dt['Family Influence'] = dt['Family Influence'].map(family_influence)

# %%
dt.dtypes
# Out:
# Field of Study                 int64
# Current Occupation             int64
# Age                            int64
# Gender                         int64
# Years of Experience            int64
# Education Level                int64
# Industry Growth Rate           int64
# Job Satisfaction               int64
# Work-Life Balance              int64
# Job Opportunities              int64
# Salary                         int64
# Job Security                   int64
# Career Change Interest         int64
# Skills Gap                     int64
# Family Influence               int64
# Mentorship Available           int64
# Certifications                 int64
# Freelancing Experience         int64
# Geographic Mobility            int64
# Professional Networks          int64
# Career Change Events           int64
# Technology Adoption            int64
# Likely to Change Occupation    int64
# dtype: object

# %%
# Guardamos el archivo una vez tratado
dt.to_csv("Dataframe_con_datos_numericos.csv", index=False)

# %%
# Ahora normalizaremos los datos
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
data = pd.read_csv('Dataframe_con_datos_numericos.csv')
scaler = MinMaxScaler()

# %%
# Separando los datos
x = data.drop(columns=['Likely to Change Occupation'])
# Out:
# (38444, 22)

# %%
# Separando los datos
y = data['Likely to Change Occupation']
y.to_csv('Likely to Change Occupation.csv', index=False)

# %%
# Transformando los datos
import pandas as pd
x_scaled = scaler.fit_transform(x)

# Convertir a dataframe los datos transformados
data_normalized = pd.DataFrame(x_scaled, columns=x.columns)
data_normalized.to_csv('data_normalized.csv', index=False)

# %%
from sklearn.model_selection import train_test_split
# Creamos los datos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(data_normalized, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Inicializar el modelo
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = model.predict(X_test)

# Evaluar el rendimiento
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}")
print(f"Classification Report: \n{classification_report(y_test, y_pred)}")
# Out:
# Accuracy: 0.9007673299518794
# Confusion Matrix:
# [[2841  371]
#  [ 392 4085]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      3212
#            1       0.92      0.91      0.91      4477
#
#     accuracy                           0.90      7689
#    macro avg       0.90      0.90      0.90      7689
# weighted avg       0.90      0.90      0.90      7689

# %%
# Exportamos ahora el modelo para no tener que volver a entrenarlo
import joblib
joblib.dump(model, 'model_sklearn.pkl')
# Out:
# ['model_sklearn.pkl']

# %%
import tensorflow as tf

# Definir el modelo de red neuronal
modeltf = tf.keras.Sequential()

# Capa de entrada (22 neuronas, correspondiente a tus 22 variables)
modeltf.add(tf.keras.layers.Dense(64, input_dim=X_train.shape[1], activation='relu'))  # Capa oculta 1

# Segunda capa oculta
modeltf.add(tf.keras.layers.Dense(32, activation='relu'))  # Capa oculta 2

# Capa de salida (1 neurona con activación sigmoide para clasificación binaria)
modeltf.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# Compilar el modelo
modeltf.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Resumen de la arquitectura del modelo
modeltf.summary()

# Entrenar el modelo
history = modeltf.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Evaluación del modelo
y_pred = (modeltf.predict(X_test) > 0.5).astype("int32")  # Predicciones

# Evaluación de métricas
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}")
print(f"Classification Report: \n{classification_report(y_test, y_pred)}")
# Out:
# /home/jdam/Documentos/programming stuff/EDA/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 64)             │         1,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Exportamos ahora el modelo para no tener que volver a entrenarlo
import joblib
joblib.dump(modeltf, 'model_tensorflow.pkl')
# Out:
# ['model_tensorflow.pkl']

# %%
#for i in data.columns: print(i)
X_test.shape
# Out:
# (7689, 22)
